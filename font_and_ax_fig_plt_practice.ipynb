# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/master.csv')

# %%
df.columns
# Out:
# Index(['country', 'year', 'sex', 'age', 'suicides_no', 'population',
#        'suicides/100k pop', 'country-year', 'HDI for year',
#        ' gdp_for_year ($) ', 'gdp_per_capita ($)', 'generation'],
#       dtype='object')

# %%
df.shape
# Out:
# (27820, 12)

# %%
fig , axi = plt.subplots(figsize=(10,5) ,ncols=2,nrows=2)

# %%
# plt.figure(figsize=(16,6))
# plt.subplot(2,2,1)
# sns.barplot(x='country',y='suicides_no',data=df)
# plt.subplot(2,2,2)
# sns.barplot(x='sex',y='suicides_no',data=df)
# plt.subplot(2,2,3)
# sns.barplot(x='age',y='suicides_no',data=df)
# plt.subplot(2,2,4)
# sns.barplot(x='generation',y='suicides_no',data=df)

# %%
plt.subplots(figsize=(5,2))
sns.barplot(x='country',y='suicides_no',data=df)
# Out:
# <Axes: xlabel='country', ylabel='suicides_no'>

# %%
plt.figure(figsize= (52))
sns.barplot(x='country',y='suicides_no',data=df)

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

fruits = ['apple', 'blueberry', 'cherry', 'orange']
counts = [40, 100, 30, 55]
bar_labels = ['red', 'blue', '_red', 'orange']
bar_colors = ['tab:red', 'tab:blue', 'tab:red', 'tab:orange']

ax.bar(fruits, counts, label=bar_labels, color=bar_colors)

ax.set_ylabel('fruit supply')
ax.set_title('Fruit supply by kind and color')
ax.legend(title='Fruit color')

plt.show()

# %%
fig2 , ax2 = plt.subplots(figsize=(3,2))

# %%
fig3 , ax3 = plt.subplots(figsize=(3,2),nrows=2,ncols=2,sharex=True)

# %%
plt.figure(figsize=(3,2),facecolor = '#F5EE1F', edgecolor='#99ffff',)
sns.barplot(x='sex',y='suicides_no',data=df, color='#0099e6')
# Out:
# <Axes: xlabel='sex', ylabel='suicides_no'>

# %%
sns.barplot(x='sex',y='suicides_no',data=df , hue='age' ,color='red')
# Out:
# <ipython-input-18-057be8e06de0>:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:red'` for the same effect.
#
#   sns.barplot(x='sex',y='suicides_no',data=df , hue='age' ,color='red')
# <Axes: xlabel='sex', ylabel='suicides_no'>

# %%
df.head()
# Out:
#    country  year     sex          age  suicides_no  population  \
# 0  Albania  1987    male  15-24 years           21      312900
# 1  Albania  1987    male  35-54 years           16      308000
# 2  Albania  1987  female  15-24 years           14      289700
# 3  Albania  1987    male    75+ years            1       21800
# 4  Albania  1987    male  25-34 years            9      274300
#
#    suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# 0               6.71  Albania1987           NaN      2,156,624,900
# 1               5.19  Albania1987           NaN      2,156,624,900
# 2               4.83  Albania1987           NaN      2,156,624,900
# 3               4.59  Albania1987           NaN      2,156,624,900
# 4               3.28  Albania1987           NaN      2,156,624,900
#
#    gdp_per_capita ($)       generation
# 0                 796     Generation X
# 1                 796           Silent
# 2                 796     Generation X
# ...

# %%
y = df['age']
x = df['sex']

# %%
plt.plot(x,y , color='#FEAC5B' , )
plt.title('line plot' , fontname='fantasy',fontweight = 'bold', fontsize = 19)
# Out:
# Text(0.5, 1.0, 'line plot')

# %%
plt.plot(x,y , color='#FEAC5B' , )
plt.title('line plot' , fontweight = 'bold', fontsize = 19)
# Out:
# Text(0.5, 1.0, 'line plot')

# %%
plt.plot(x,y , color='#FEAC5B' , )
plt.title('line plot' , fontname='MS Reference Sans Serif',fontweight = 'bold', fontsize = 19)
# Out:
# Text(0.5, 1.0, 'line plot')
# WARNING:matplotlib.font_manager:findfont: Font family 'MS Reference Sans Serif' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'MS Reference Sans Serif' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'MS Reference Sans Serif' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'MS Reference Sans Serif' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'MS Reference Sans Serif' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'MS Reference Sans Serif' not found.

# %%
# import matplotlib.pyplot as plt
# import seaborn as sns
# import pandas as pd

# # Example DataFrame
# data = {
#     'country': ['Country A', 'Country B', 'Country C'],
#     'suicides_no': [100, 150, 200]
# }
# df = pd.DataFrame(data)

# # Set custom font properties
# plt.rcParams['font.family'] = 'serif'  # Font family
# plt.rcParams['font.serif'] = ['Times New Roman']  # Specific font name

# # Alternative way to set font properties directly in plot
# # plt.rc('font', family='serif', serif='Times New Roman')

# # Create the plot
# fig, ax = plt.subplots(figsize=(5, 2))
# sns.barplot(x='country', y='suicides_no', data=df, ax=ax)

# # Set additional font properties for specific text elements if needed
# ax.set_xlabel('Country', fontsize=12, fontweight='bold', fontname='Times New Roman')
# ax.set_ylabel('Number of Suicides', fontsize=12, fontweight='bold', fontname='Times New Roman')
# ax.set_title('Suicide Numbers by Country', fontsize=14, fontweight='bold', fontname='Times New Roman')

# # Show the plot
# plt.show()

# %%
plt.subplots(figsize=(6,4))
plt.xlabel('suicides_no')
plt.ylabel('age')
# Out:
# Text(0, 0.5, 'age')

# %%
fig7 , ax7 = plt.subplots(figsize=(6,4))
plt.title('this is a title')
ax7.set_xlabel('suicides_no')
ax7.set_ylabel('age')
plt.text(0.5,0.5,'this inner text', ha='center',fontsize = 20, fontweight = 'bold')
# Out:
# Text(0.5, 0.5, 'this inner text')

# %% [markdown]
# abb kebe

# %%
fig7 , ax7 = plt.subplots(figsize=(6,4))
plt.title('this is a title')
ax7.set_xlabel('suicides_no')
ax7.set_ylabel('age')
ax7.text(0.5,0.5,'this inner text', ha='center',fontsize = 20, fontweight = 'bold')
# Out:
# Text(0.5, 0.5, 'this inner text')

# %%
fig7 , ax7 = plt.subplots(figsize=(6,4))
plt.title('this is a title')
ax7.set_xlabel('suicides_no')
ax7.set_ylabel('age')
fig7.text(0.5,0.5,'this inner text', ha='center',fontsize = 20, fontweight = 'bold')
# Out:
# Text(0.5, 0.5, 'this inner text')

# %%
plt.figure(figsize=(2,1))
plt.title('hello')
plt.xlabel('suicides_no')
plt.ylabel('age')
# Out:
# Text(0, 0.5, 'age')

# %%
fig8 , ax8 = plt.subplots(figsize=(6,4),nrows=2,ncols=2,)
plt.subplots_adjust(wspace=1,hspace=1)

plt.subplot(2,2,1)
plt.title('hello')
plt.xlabel('suicides_no')
plt.ylabel('age')
plt.subplot(2,2,2)
plt.title('hello')
plt.xlabel('suicides_no')
plt.ylabel('age')

ax8[1,0].set_title('earth')
ax8[1,0].set_xlabel('moon')
# Out:
# Text(0.5, 0, 'moon')

# %%
fig , ax = plt.subplots(figsize=(6,4),nrows=2,ncols=2 , sharex= True)
plt.title('hello')
plt.xlabel('suicides_no')
plt.ylabel('age')
# Out:
# Text(0, 0.5, 'age')

# %%
# plt.figure(figsize=(16,6))
# plt.subplot(2,2,1)
# sns.barplot(x='country',y='suicides_no',data=df)
# plt.subplot(2,2,2)
# sns.barplot(x='sex',y='suicides_no',data=df)
# plt.subplot(2,2,3)
# sns.barplot(x='age',y='suicides_no',data=df)
# plt.subplot(2,2,4)
# sns.barplot(x='generation',y='suicides_no',data=df)

# %%
fig9, ax9 = plt.subplots(figsize = (15,8),nrows=2 , ncols=3)
plt.subplots_adjust(wspace = 0.4 , hspace = 0.4)
plt.subplot(2,3,1)
plt.title('hello',rotation= 45,loc='right' ,color ='red' ,backgroundcolor='green')
ax9[0,2].set_title('This is earth🐍',animated= True)
ax9[0,2].set_xlabel('The Human')
ax9[0,2].set_ylabel('Living')
# Out:
# Text(0, 0.5, 'Living')
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 128013 (\N{SNAKE}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128013 (\N{SNAKE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
fig10 , ax10 = plt.subplots(figsize = (10,6), nrows = 2 ,ncols = 2)
plt.subplots_adjust(wspace = 0.4 , hspace = 0.3)

# %%
fig10 , ax10 = plt.subplots(figsize = (10,6), nrows = 2 ,ncols = 2)
plt.subplots_adjust(wspace = 0.5 , hspace = 0.5)
plt.subplot(2,2,1)
plt.title('This is my first subplot',color = 'red',fontweight = 'bold' , fontsize = 10)
plt.xlabel('mummy',color = '#1bc900')
plt.ylabel('papa',color = '#206af5' , rotation = 45)
plt.subplot(2,2,2)
plt.title('This is my second subplot',color = '#54ffeb', fontsize = 14)
plt.xlabel('dadi' , color = '#1bc900')
plt.ylabel('dada', color = '#206af5' , rotation = 45)
ax10[1,0].set_title('This is my third subplot', color = '#fffc45' , fontsize = 15 , fontweight = 'bold')
ax10[1,0].set_xlabel('nani', color = '#1bc900')
ax10[1,0].set_ylabel('nana', color = '#206af5' , rotation = 45)
# Out:
# Text(0, 0.5, 'nana')

# %%
fig11 , ax11 = plt.subplots(figsize = (10,5), nrows = 2 , ncols = 2 , facecolor = '#ffef45' )
plt.subplots_adjust(wspace = 0.5 , hspace = 0.5 )
plt.subplot(2,2,1 , facecolor = 'red')
plt.title('hello')
plt.xlabel('Earth')
plt.ylabel('Moon')
plt.text(0.5,0.5 , 'This is inside' )
plt.subplot(2,2,2, facecolor = 'green')
ax11[0,1].set_title('This is my second practice', fontsize = 15 , fontweight = 'bold')
ax11[0,1].set_xlabel('Sun')
ax11[0,1].set_ylabel('Saturn')
# Out:
# <ipython-input-25-c235db95e0f1>:3: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(2,2,1 , facecolor = 'red')
# <ipython-input-25-c235db95e0f1>:8: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(2,2,2, facecolor = 'green')
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-c235db95e0f1> in <cell line: 9>()
#       7 plt.text(0.5,0.5 , 'This is inside' )
#       8 plt.subplot(2,2,2, facecolor = 'green')
# ----> 9 ax11[0,1].set_title('This is my second practice', fontsize = 15 , fontweight = 'bold')
#      10 ax11[0,1].set_xlabel('Sun')
#      11 ax11[0,1].set_ylabel('Saturn')
#
# ...

# %%
plt.subplot(2,2,1)
plt.title('hello')
# Out:
# Text(0.5, 1.0, 'hello')

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery')

# Make data
x = [1, 1, 2, 2]
y = [1, 2, 1, 2]
z = [0, 0, 0, 0]
dx = np.ones_like(x)*0.5
dy = np.ones_like(x)*0.5
dz = [2, 3, 1, 4]

# Plot
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
ax.bar3d(x, y, z, dx, dy, dz)

ax.set(xticklabels=[],
       yticklabels=[],
       zticklabels=[])

plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# %%
font_path = '/content/Burbank Big Condensed Font.otf' # Replace with the actual path

font = fm.FontProperties(fname = font_path)

# %%
fig12 ,ax12 = plt.subplots(figsize = (13,7) , nrows = 2 , ncols = 2 , facecolor = '#ffffff')
plt.subplots_adjust(wspace = 0.5 , hspace = 0.5)
label3 = [1,2,3,4,5,6,7,8,9]
plt.subplot(2,2,2)
plt.xticks(label3 , color = 'red' , fontsize = 15)
plt.yticks(label3 , color = 'green' , fontsize = 12)
# plt.margins(0.2)
plt.title('My Plot',fontproperties=font , fontsize = 15 , color = 'black' )  # Apply to title
plt.xlabel('X Label', fontproperties=font ,color = 'black')  # Apply to x-axis label
plt.ylabel('Y Label', fontproperties=font , rotation = 0)  # Apply to y-axis label
plt.subplot(2,2,3)
plt.title('Burbank font testing' , fontproperties = font , fontsize =20 , color = '#00fffb' )
ax12 = ax12.flatten()

ax12[0].set_title('Thsi is preactice' , color = 'red' , fontsize = 15 , fontweight = 'bold' ,)
# Out:
# Text(0.5, 1.0, 'Thsi is preactice')

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# %%
fontpath = '/content/Roboto-MediumItalic.ttf'
Roboto1 = fm.FontProperties(fname= fontpath)

# %%
title = ['First title' , 'Second title' , 'Third title' , 'Fourth title']
xlabel = ['xlabel1' , 'xlabel2' , 'xlabel3' , 'slabel4']
ylabel = ['ylabel1' , 'ylabel2' , 'ylabel3' , 'ylanle4']
xtickslabel = [1,2,3,4,5,6,7,8,9]
ytickslabel = [1,2,3,4,5,6,7,8,9]
color = ['#ff6200','#ffbf00','#827d82','#1eff00','#00fff7','#001aff','#dd00ff']

# %%
fig13 , ax13 = plt.subplots(figsize = (15,8),nrows = 2 , ncols = 2 ,facecolor = color[2])
plt.subplots_adjust(wspace = 0.6 , hspace = 0.4)
ax13 = ax13.flatten()
plt.subplot(2,2,1)
plt.title(title[0], color = color[0] , fontsize = 15 , fontproperties = Roboto1)
plt.xlabel(xlabel[0] , color = color[1] , fontproperties = Roboto1 , fontsize = 13)
plt.ylabel(ylabel[0], color = color[1] , fontproperties = Roboto1 , fontsize = 13 , rotation = 0 )
plt.xticks(xtickslabel , color = color[6] , fontsize = 11 )
plt.yticks(ytickslabel , color = color[3] , fontsize = 11)
ax13[1].set_title(title[1], color = color[3] , fontsize = 13 , fontproperties = Roboto1 )
# Out:
# Text(0.5, 1.0, 'Second title')

# %%
df1 = pd.read_csv('/content/archive (3).zip')

# %%
df1
# Out:
#           country  year     sex          age  suicides_no  population  \
# 0         Albania  1987    male  15-24 years           21      312900
# 1         Albania  1987    male  35-54 years           16      308000
# 2         Albania  1987  female  15-24 years           14      289700
# 3         Albania  1987    male    75+ years            1       21800
# 4         Albania  1987    male  25-34 years            9      274300
# ...           ...   ...     ...          ...          ...         ...
# 27815  Uzbekistan  2014  female  35-54 years          107     3620833
# 27816  Uzbekistan  2014  female    75+ years            9      348465
# 27817  Uzbekistan  2014    male   5-14 years           60     2762158
# 27818  Uzbekistan  2014  female   5-14 years           44     2631600
# 27819  Uzbekistan  2014  female  55-74 years           21     1438935
#
#        suicides/100k pop    country-year  HDI for year  gdp_for_year ($)   \
# ...

# %%
plt.bar('sex', height = 0.2)
# Out:
# <BarContainer object of 1 artists>

# %%
plt.bar('hello', height = 0.6)
# Out:
# <BarContainer object of 1 artists>

# %%
year = [1500, 1510,1560]
plt.bar(year , height = 0.5)
# Out:
# <BarContainer object of 3 artists>

# %%
year = ['1990', '2000']
plt.bar(year , height = 1)
# Out:
# <BarContainer object of 2 artists>

# %%
array = np.random.randint(1,100,10)

# %%
array
# Out:
# array([17, 41, 18, 69, 75, 39, 73, 38, 16,  4])

# %%
x = df1.groupby(['year']).sum(['population'])

# %%
x.head()
# Out:
#       suicides_no  population  suicides/100k pop  HDI for year  \
# year
# 1985       116063  1008600086            6811.89       310.428
# 1986       120670  1029909613            6579.84         0.000
# 1987       126842  1095029726            7545.45         0.000
# 1988       121026  1054094424            7473.13         0.000
# 1989       160244  1225514347            8036.54         0.000
#
#       gdp_per_capita ($)
# year
# 1985             3508548
# 1986             4104636
# 1987             5645760
# 1988             5870508
# 1989             6068424

# %%
fig14 , ax14 = plt.subplots(figsize = (10,5))
plt.subplots_adjust(wspace = 0.3 , hspace = 0.3)
plt.title('Year Populaton' , fontproperties = Roboto1 , fontsize = 20  , pad = 30)
plt.xlabel('Year' , fontproperties = Roboto1 , fontsize = 17 , labelpad = 20 )
plt.ylabel('Population' , fontproperties = Roboto1 , fontsize = 15 , rotation = 0, labelpad = 30)
# Out:
# Text(0, 0.5, 'Population')

# %%
x.head()
# Out:
#       suicides_no  population  suicides/100k pop  HDI for year  \
# year
# 1985       116063  1008600086            6811.89       310.428
# 1986       120670  1029909613            6579.84         0.000
# 1987       126842  1095029726            7545.45         0.000
# 1988       121026  1054094424            7473.13         0.000
# 1989       160244  1225514347            8036.54         0.000
#
#       gdp_per_capita ($)
# year
# 1985             3508548
# 1986             4104636
# 1987             5645760
# 1988             5870508
# 1989             6068424

# %%
x[['population']]

# %%
year = pd.DataFrame(x.iloc[:,:0])
population = pd.DataFrame(x.iloc[:,1:2])


ax14.bar( year , populatoin )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-113-8007bc12f0f4> in <cell line: 5>()
#       3
#       4
# ----> 5 ax14.bar( year , populatoin )
#
# NameError: name 'populatoin' is not defined

# %%
ax14.bar( year , populatoin , df = year,populaton)
# Out:
#   File "<ipython-input-111-32944ca5c3db>", line 1
#     ax14.bar( year , populatoin , df = year,populaton)
#                                                      ^
# SyntaxError: positional argument follows keyword argument
